# %% [markdown]
# # Import

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Load Data

# %%
df = pd.read_csv("./static/data/data.csv",encoding='latin-1')
print(df.shape)
df.head()
# Out:
# (15433, 11)
#        City    Year     Sport Discipline           Event  \
# 0  Montreal  1976.0  Aquatics     Diving  3m springboard
# 1  Montreal  1976.0  Aquatics     Diving  3m springboard
# 2  Montreal  1976.0  Aquatics     Diving  3m springboard
# 3  Montreal  1976.0  Aquatics     Diving  3m springboard
# 4  Montreal  1976.0  Aquatics     Diving    10m platform
#
#                     Athlete Gender Country_Code        Country Event_gender  \
# 0           KÖHLER, Christa  Women          GDR   East Germany            W
# 1       KOSENKOV, Aleksandr    Men          URS   Soviet Union            M
# 2      BOGGS, Philip George    Men          USA  United States            M
# 3  CAGNOTTO, Giorgio Franco    Men          ITA          Italy            M
# 4    WILSON, Deborah Keplar  Women          USA  United States            W
#
#     Medal
# 0  Silver
# 1  Bronze
# 2    Gold
# 3  Silver
# 4  Bronze

# %%
len(set(df["Discipline"].values))
# Out:
# 42

# %%
len(set(df["Country"].values))
# Out:
# 128

# %% [markdown]
# # Preprocessing

# %%
df.dropna(axis=0,inplace=True)
print(df.shape)
# Out:
# (15316, 11)

# %%
rep1 = df[df["Medal"]=="Gold"].groupby("Country").count().reset_index()

rep1.sort_values(by="City",ascending=False)
# Out:
#           Country  City  Year  Sport  Discipline  Event  Athlete  Gender  \
# 82  United States   928   928    928         928    928      928     928
# 67   Soviet Union   439   439    439         439    439      439     439
# 24   East Germany   286   286    286         286    286      286     286
# 32        Germany   237   237    237         237    237      237     237
# 15          China   234   234    234         234    234      234     234
# ..            ...   ...   ...    ...         ...    ...      ...     ...
# 59         Panama     1     1      1           1      1        1       1
# 11        Burundi     1     1      1           1      1        1       1
# 69       Suriname     1     1      1           1      1        1       1
# 16       Colombia     1     1      1           1      1        1       1
# 76        Tunisia     1     1      1           1      1        1       1
#
#     Country_Code  Event_gender  Medal
# 82           928           928    928
# ...

# %%
test = df.groupby(["Country","Gender"]).count().reset_index()
test[test["Country"]=="Algeria"]
# Out:
#    Country Gender  City  Year  Sport  Discipline  Event  Athlete  \
# 1  Algeria    Men    11    11     11          11     11       11
# 2  Algeria  Women     3     3      3           3      3        3
#
#    Country_Code  Event_gender  Medal
# 1            11            11     11
# 2             3             3      3

# %%
df
# Out:
#            City    Year      Sport       Discipline           Event  \
# 0      Montreal  1976.0   Aquatics           Diving  3m springboard
# 1      Montreal  1976.0   Aquatics           Diving  3m springboard
# 2      Montreal  1976.0   Aquatics           Diving  3m springboard
# 3      Montreal  1976.0   Aquatics           Diving  3m springboard
# 4      Montreal  1976.0   Aquatics           Diving    10m platform
# ...         ...     ...        ...              ...             ...
# 15428   Beijing  2008.0  Wrestling  Wrestling Gre-R       66 - 74kg
# 15429   Beijing  2008.0  Wrestling  Wrestling Gre-R       66 - 74kg
# 15430   Beijing  2008.0  Wrestling  Wrestling Gre-R       55 - 60kg
# 15431   Beijing  2008.0  Wrestling  Wrestling Gre-R       60 - 66kg
# 15432   Beijing  2008.0  Wrestling  Wrestling Gre-R      96 - 120kg
#
#                         Athlete Gender Country_Code        Country  \
# 0               KÖHLER, Christa  Women          GDR   East Germany
# ...

# %%
df[df.Year ==1976].drop_duplicates(["Event"],keep='first')
# Out:
#           City    Year      Sport       Discipline  \
# 0     Montreal  1976.0   Aquatics           Diving
# 4     Montreal  1976.0   Aquatics           Diving
# 12    Montreal  1976.0   Aquatics         Swimming
# 13    Montreal  1976.0   Aquatics         Swimming
# 15    Montreal  1976.0   Aquatics         Swimming
# ...        ...     ...        ...              ...
# 1367  Montreal  1976.0  Wrestling  Wrestling Free.
# 1371  Montreal  1976.0  Wrestling  Wrestling Free.
# 1374  Montreal  1976.0  Wrestling  Wrestling Free.
# 1375  Montreal  1976.0  Wrestling  Wrestling Free.
# 1377  Montreal  1976.0  Wrestling  Wrestling Free.
#
#                               Event                    Athlete Gender  \
# 0                    3m springboard            KÖHLER, Christa  Women
# 4                      10m platform     WILSON, Deborah Keplar  Women
# 12           4x100m freestyle relay  BABASHOFF, Shirley Farber  Women
# ...

# %%
df
# Out:
#            City    Year      Sport       Discipline           Event  \
# 0      Montreal  1976.0   Aquatics           Diving  3m springboard
# 1      Montreal  1976.0   Aquatics           Diving  3m springboard
# 2      Montreal  1976.0   Aquatics           Diving  3m springboard
# 3      Montreal  1976.0   Aquatics           Diving  3m springboard
# 4      Montreal  1976.0   Aquatics           Diving    10m platform
# ...         ...     ...        ...              ...             ...
# 15428   Beijing  2008.0  Wrestling  Wrestling Gre-R       66 - 74kg
# 15429   Beijing  2008.0  Wrestling  Wrestling Gre-R       66 - 74kg
# 15430   Beijing  2008.0  Wrestling  Wrestling Gre-R       55 - 60kg
# 15431   Beijing  2008.0  Wrestling  Wrestling Gre-R       60 - 66kg
# 15432   Beijing  2008.0  Wrestling  Wrestling Gre-R      96 - 120kg
#
#                         Athlete Gender Country_Code        Country  \
# 0               KÖHLER, Christa  Women          GDR   East Germany
# ...

# %%
df["nb"] = 1
temp = df.drop_duplicates(subset=["Year","Athlete"]).groupby("Year").count().reset_index()[["Year","nb"]]
del df["nb"]
df = pd.merge(df,temp,on="Year")

# %%
df.to_json("./static/data/preprocessed_data.json",orient="records")
